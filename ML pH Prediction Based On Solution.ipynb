# %% [markdown]
# # **ML pH Prediction Based On Solution**

# %%
#1st step we will all the Important libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
# all the above libraries are necessary to train our data.

# %%
# 2nd step we will import the data_set
#we will import our CSV file which contain data_set of our model
df=pd.read_csv('pH_prediction.csv')

#now our data is successfully and now we can work on it

# %% [markdown]
# ### Data Filtering and Handeling Mssing_Values

# %%
df.head()
# Out:
#    Sample_ID  Temperature_C  Conductivity_mS      TDS_ppm  Turbidity_NTU  \
# 0          1      24.810634         5.603261  1361.770839       5.719959
# 1          2      53.352076         5.316087  1603.528725       8.054323
# 2          3      79.835667        18.171964   538.412403       7.601609
# 3          4      68.577991         5.366151  1268.504494       1.538999
# 4          5      74.524892         5.803020  1164.904667       1.492495
#
#    Salinity_ppt        pH
# 0     15.745421  7.241285
# 1     18.937426  4.861932
# 2     34.181896  8.361973
# 3     13.600175  7.065581
# 4     34.785987  4.786019

# %%
df.isnull() # chechking the null values
# Out:
#      Sample_ID  Temperature_C  Conductivity_mS  TDS_ppm  Turbidity_NTU  \
# 0        False          False            False    False          False
# 1        False          False            False    False          False
# 2        False          False            False    False          False
# 3        False          False            False    False          False
# 4        False          False            False    False          False
# ..         ...            ...              ...      ...            ...
# 995      False          False            False    False          False
# 996      False          False            False    False          False
# 997      False          False            False    False          False
# 998      False          False            False    False          False
# 999      False          False            False    False          False
#
#      Salinity_ppt     pH
# 0           False  False
# 1           False  False
# 2           False  False
# ...

# %%
df.info() # checking the info of the data_set
          #so our data_set is clean and neat and now we can work on it and try get to train the model best.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sample_ID        1000 non-null   int64
#  1   Temperature_C    1000 non-null   float64
#  2   Conductivity_mS  1000 non-null   float64
#  3   TDS_ppm          1000 non-null   float64
#  4   Turbidity_NTU    1000 non-null   float64
#  5   Salinity_ppt     1000 non-null   float64
#  6   pH               1000 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 54.8 KB

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.columns
# Out:
# Index(['Sample_ID', 'Temperature_C', 'Conductivity_mS', 'TDS_ppm',
#        'Turbidity_NTU', 'Salinity_ppt', 'pH'],
#       dtype='object')

# %% [markdown]
# ### Use Of Scikit_Learn

# %%
# '''so now we  use Scikit learn because it is ML library and we can perform our tasks on it'''b

# %%
# now we will target our features and labels
#1st we will assign the feature column
x=df[['Conductivity_mS','Temperature_C']]
# 2nd we target the label and predict the output result
y=df[['pH']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=47)

# %%
### cal the model and train the model
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# model.predict([[74.524892,5.803020]])
# Out:
# C:\Users\Nosha\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[5.84763123]])

# %%
# import matricss to Evalutate the model we have just trained
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,r2_score,root_mean_squared_error,mean_squared_error

# %% [markdown]
# ## *Results*

# %%
y_pred=model.predict(x_test)
print(f'MAE:{mean_absolute_error(y_test,y_pred)}')
print(f'MAPE:{mean_absolute_percentage_error(y_test,y_pred)}')
print(f'R2:{r2_score(y_test,y_pred)}')
print(f'root_mean_squared_error:{root_mean_squared_error(y_test,y_pred)}')
# Out:
# MAE:1.1898290459709893
# MAPE:0.19176127453802053
# R2:0.00447613467365493
# root_mean_squared_error:1.3803335683689983

# %% [markdown]
# ## **Summary of the Project**

# %% [markdown]
# **This project aims to develop a predictive model that estimates the pH of a solution based on its solute concentration and temperature. pH is a crucial chemical property affecting reaction rates, solubility, and biological activity. Traditional pH measurement methods, such as pH meters, require physical sampling and calibration, which can be time-consuming and equipment-dependent.**
#
# *Using a dataset containing pH values alongside corresponding concentrations and temperatures, we applied supervised machine learning regression techniques to model the relationship between these variables. Data preprocessing included handling missing values, standardizing features, and splitting the dataset into training and testing sets.
#
# **The model was trained to recognize patterns in how concentration and temperature influence hydrogen ion activity in solution, ultimately predicting pH with high accuracy. Performance was evaluated using metrics such as Mean Absolute Error (MAE), Mean Squared Error (MSE), and R² score.**
#
# This approach offers a cost-effective and rapid alternative to traditional pH measurement methods, with potential applications in analytical chemistry, environmental monitoring, food industry, and chemical manufacturing.
